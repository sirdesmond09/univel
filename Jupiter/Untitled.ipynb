# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv("cancer.csv")
# data
# sns.lmplot("cancer","population", data = data, fit_reg=True)
# sns.scatterplot("cancer","population", data = data)
# sns.barplot("cancer","population", data = data,)
# sns.boxenplot("cancer","population", data = data)
sns.boxplot("cancer","population", data = data)
